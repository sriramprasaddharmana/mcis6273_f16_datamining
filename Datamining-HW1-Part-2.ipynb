# %% [markdown]
# Loading the basic libs of Python for this assignemnt.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import requests
import pandas as pd
import numpy as np
import math
import operator 
from io import StringIO
from scipy.spatial.distance import squareform, pdist

# %% [markdown]
# Part 2 - Implement the k-Nearest Neighbor algorithm in Python using the Euclidean distance metric.

# %%
pd.realEstData = pd.read_csv('Sacramentorealestatetransactions.csv', names=['street', 'city', 'zip', 'state', 'beds', 'baths', 'sq_ft', 'type', 'sale_date','price', 'latitude', 'longitude'])

# %% [markdown]
# extract the required field to process.

# %%
pd.realEstData = pd.realEstData[['street', 'beds', 'baths', 'sq_ft', 'price']]
pd.realEstData = pd.realEstData.iloc[1:]
pd.realEstData.set_index(['street'])
pd.realEstData = pd.realEstData.iloc[1:]

# %%
pd.realEstData.head()
df = pd.realEstData
df.head()
# Out:
#                 street beds baths sq_ft  price
# 4     2805 JANETTE WAY    2     1   852  69307
# 5      6001 MCMAHON DR    2     1   797  81900
# 6   5828 PEPPERMILL CT    3     1  1122  89921
# 7  6048 OGDEN NASH WAY    3     2  1104  90895
# 8        2561 19TH AVE    3     1  1177  91002

# %% [markdown]
# computing the similarity between the data points

# %%
for i in df["street"]:
    for j in df["street"]:
        row = df[df["street"] == j][["beds", "baths"]]
        latitude = row["beds"].tolist()[0]
        longitude = row["baths"].tolist()[0]
        df.loc[df['street'] == i, j] = ((df["beds"] - latitude)**2 + (df["baths"] - longitude)**2)**0.5
df = df.drop(["street", "beds", "baths"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/ops.py in na_op(x, y)
#     552             result = expressions.evaluate(op, str_rep, x, y,
# --> 553                                           raise_on_error=True, **eval_kwargs)
#     554         except TypeError:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/computation/expressions.py in evaluate(op, op_str, a, b, raise_on_error, use_numexpr, **eval_kwargs)
#     217         return _evaluate(op, op_str, a, b, raise_on_error=raise_on_error,
# --> 218                          **eval_kwargs)
#     219     return _evaluate_standard(op, op_str, a, b, raise_on_error=raise_on_error)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/computation/expressions.py in _evaluate_standard(op, op_str, a, b, raise_on_error, **eval_kwargs)
#      70         _store_test_result(False)
# ---> 71     return op(a, b)
#      72
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-eccaca3cc4e1> in <module>()
#       4         latitude = row["beds"].tolist()[0]
#       5         longitude = row["baths"].tolist()[0]
# ----> 6         df.loc[df['street'] == i, j] = ((df["beds"] - latitude)**2 + (df["baths"] - longitude)**2)**0.5
#       7 df = df.drop(["street", "beds", "baths"], axis=1)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/ops.py in wrapper(left, right, name, na_op)
#     616                 lvalues = lvalues.values
#     617
# --> 618             return left._constructor(wrap_results(na_op(lvalues, rvalues)),
#     619                                      index=left.index, name=left.name,
#     620                                      dtype=dtype)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/ops.py in na_op(x, y)
#     561                 result = np.empty(len(x), dtype=x.dtype)
#     562                 mask = notnull(x)
# --> 563                 result[mask] = op(x[mask], y)
#     564             else:
#     565                 raise TypeError("{typ} cannot perform the operation {op}".format(typ=type(x).__name__,op=str_rep))
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
